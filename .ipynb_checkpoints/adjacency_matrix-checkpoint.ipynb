# %%
import numpy as np
import igraph as ig
import pandas as pd
from numpy.linalg import norm

def l1_row(row):
    row_sum = norm(row, ord=1)
    if row_sum == 0:
        return row
    else:
        return row / row_sum

def norm_rows(df):
    return df.apply(l1_row,axis=1)

# list of all projects / accounts - will specify the ordering
proj_meta = pd.read_csv('data/cargo-dependencies-meta.csv', delimiter=',', dtype={'ID': 'Int64'}).dropna();
proj_ids = proj_meta['ID'].tolist()
labels = proj_meta['Name'].tolist()
# acc = ['a1', 'a2', 'a3']
# labels = np.concatenate((proj,acc), axis=0)

proj_meta.head()
# Out:
#       ID          Name Platform
# 0  30742        acacia    Cargo
# 1  30745           aio    Cargo
# 2  30746  advapi32-sys    Cargo
# 3  30747        alfred    Cargo
# 4  30748     algebloat    Cargo

# %%
deps = pd.read_csv('data/cargo-dependencies.csv', delimiter=',');
deps.head()
# Out:
#    FROM_ID   TO_ID
# 0    30742   31187
# 1    30742   31296
# 2    30742   31295
# 3    30742   31085
# 4    30742  428702

# %%
raw_contrib = pd.read_csv('data/gh-contributions.csv', delimiter=",").dropna();
rust_contrib = raw_contrib[raw_contrib['Name'].isin(labels)];
rust_contrib.head()
# Out:
#                                              maintainer                  repo  \
# 260   fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...      Asus-T100/kernel
# 283   fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...  julianjmaurer/kernel
# 308   fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...           jigpu/input
# 400   fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...            Wenzel/kvm
# 1081  69652caca27c8b940640ad396ab71f93cacec34f@linux...      Asus-T100/kernel
#
#      contributions    Name
# 260          53029  kernel
# 283          52489  kernel
# 308          51297   input
# 400          48096     kvm
# 1081         42306  kernel

# %%
contributers = rust_contrib['maintainer'].unique().tolist()
contrib = rust_contrib.merge(proj_meta)
contrib.head()
# Out:
#                                           maintainer                  repo  \
# 0  fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...      Asus-T100/kernel
# 1  fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...  julianjmaurer/kernel
# 2  69652caca27c8b940640ad396ab71f93cacec34f@linux...      Asus-T100/kernel
# 3  fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davem...      markgross/kernel
# 4  69652caca27c8b940640ad396ab71f93cacec34f@linux...  julianjmaurer/kernel
#
#   contributions    Name       ID Platform
# 0         53029  kernel  1748045    Cargo
# 1         52489  kernel  1748045    Cargo
# 2         42306  kernel  1748045    Cargo
# 3         42034  kernel  1748045    Cargo
# 4         41961  kernel  1748045    Cargo

# %%
# create the contributions matrix
def adj_from_contrib(contrib, contributers, all_ids):
    adj = pd.DataFrame(0, columns=contributers, index=all_ids)
    for index, row in contrib.iterrows():
        adj.at[row['ID'], row['maintainer']] = row['contributions']
    return adj

adj_contrib = adj_from_contrib(contrib, contributers, proj_ids);
adj_contrib.head()
# Out:
#        fe08d3c717adf2ae63592e4c9aec6e3e404d8e3e@davemloft.net  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        69652caca27c8b940640ad396ab71f93cacec34f@linux-foundation.org  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        8081031fe20c252106f58a6c5b2ce840596f0a83@gnu.org  \
# 30742                                                 0
# 30745                                                 0
# 30746                                                 0
# 30747                                                 0
# 30748                                                 0
#
#        4645f7897fd33786a2ee1264d590b3c400559d85@linuxfoundation.org  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        746aced590a184ef4169166e753f7c211e32e5fc@tensorflow.org  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        a6723cc3f76163bf7adb636a73ac3b0ceb3e6b9b@pobox.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        0ba4af815980827fd28782804f80675b937ef955@gmx.at  \
# 30742                                                0
# 30745                                                0
# 30746                                                0
# 30747                                                0
# 30748                                                0
#
#        e7aaeebdf2ba19688320140447f4e2358a6055d6@nondot.org  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        3697fa5d1b229f59097c7d14eeabccb8d36f99e1@localhost  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        7b7a306ffc9c5a3f3ff25b7f8591088725a44427@odileeds.org  ...  \
# 30742                                                  0      ...
# 30745                                                  0      ...
# 30746                                                  0      ...
# 30747                                                  0      ...
# 30748                                                  0      ...
#
#        4f1ea4f09db2aaafb0a92c0b9e57751121ed6647@xiala.net  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        9e1f59042135645134cacd36170d31d95d24c465@redhat.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        a28d868c774dff7f8f368eb3f092f513ba819c6a@coreos.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        80b24d51bbcd1ba9a2ce6b5fe97e28c44f9ff374@arandomurl.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        55107e193e648a27778fa98736b2e8e24b3cd6e1@cygnus  \
# 30742                                                0
# 30745                                                0
# 30746                                                0
# 30747                                                0
# 30748                                                0
#
#        949b85f5a39b28e610920959d99aa52020044ae1@google.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        2e8175c327a6ef2d99764f30d3e9e7982997195e@kiste.(none)  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        e48e2233792641fdb3ce137e343feb7922da11a6@mawhrin.net  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        fba2c9f764caacc5f58f566a6af2a5167419c18f@gmail.com  \
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
#        7478dba6682c631c29bb5d8db3571688fdd8aa67@shike2.com
# 30742                                                  0
# 30745                                                  0
# 30746                                                  0
# 30747                                                  0
# 30748                                                  0
#
# [5 rows x 48926 columns]

# %%
# create the maintainers matrix (for now empty)
adj_maintain = pd.DataFrame(0, columns=contributers, index=proj_ids)

# %%
# create the dependency matrix
def adj_via_from_to(from_to, all_ids):
    adj = pd.DataFrame(0, columns=all_ids, index=all_ids)
    for index, row in from_to.iterrows():
        if row['FROM_ID'] in adj.index.tolist():
            adj.at[row['FROM_ID'], row['TO_ID']] = 1
    return adj

adjdf = adj_via_from_to(deps, proj_ids);
adjdf.head()
# Out:
#        30742    30745    30746    30747    30748    30750    30751    30753    \
# 30742        0        0        0        0        0        0        0        0
# 30745        0        0        0        0        0        0        0        0
# 30746        0        0        0        0        0        0        0        0
# 30747        0        0        0        0        0        0        0        0
# 30748        0        0        0        0        0        0        0        0
#
#        30754    30755    ...  3469060  3394154  3405396  3480649  3483337  \
# 30742        0        0  ...        0        0        0        0        0
# 30745        0        0  ...        0        0        0        0        0
# 30746        0        0  ...        0        0        0        0        0
# 30747        0        0  ...        0        0        0        0        0
# 30748        0        0  ...        0        0        0        0        0
#
#        3483781  3483812  2683436  31398    2682138
# 30742        0        0        0        0        0
# 30745        0        0        0        0        0
# 30746        0        0        0        0        0
# 30747        0        0        0        0        0
# 30748        0        0        0        0        0
#
# [5 rows x 17228 columns]

# %%
# create the adjacency matrix from projects and contributions

# ---- parameters that can be tweaked:
# weight variables of edges of G
## project -> account
d = 4.0 / 7.0
m = 2.0 / 7.0
c = 1.0 / 7.0
## account -> project
m_ = 3.0 / 5.0
c_ = 2.0 / 5.0

# dapening factors
e_proj = 0.9
e_account = 0.1

# number of iterations
niter = 1000

#  ----------------------------------

def adj_p_and_acc(D, C, M):
    acc = contributers
    acc0 = pd.DataFrame(np.zeros((np.size(acc),np.size(acc))), columns=acc, index=acc)

    p_p = d * norm_rows(D)
    p_a = m * norm_rows(M) + c * norm_rows(C)
    a_p = (m_ * M.transpose()).multiply(norm_rows(C.transpose())) + (c_ * norm_rows(C.transpose()))
    # combine the matrices
    return norm_rows(pd.concat([pd.concat([p_p,a_p], axis=0),pd.concat([p_a,acc0], axis=0)], axis=1))

adj_all = adj_p_and_acc(adjdf, adj_contrib, adj_maintain)
adj_all.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-34-77e2704cb16e> in <module>
#      30     return norm_rows(pd.concat([pd.concat([p_p,a_p], axis=0),pd.concat([p_a,acc0], axis=0)], axis=1))
#      31
# ---> 32 adj_all = adj_p_and_acc(adjdf, adj_contrib, adj_maintain)
#      33 adj_all.head()
#
# <ipython-input-34-77e2704cb16e> in adj_p_and_acc(D, C, M)
#      25
#      26     p_p = d * norm_rows(D)
# ---> 27     p_a = m * norm_rows(M) + c * norm_rows(C)
#      28     a_p = (m_ * M.transpose()).multiply(norm_rows(C.transpose())) + (c_ * norm_rows(C.transpose()))
#      29     # combine the matrices
#
# <ipython-input-6-11b8000e0ca4> in norm_rows(df)
#      12
#      13 def norm_rows(df):
# ---> 14     return df.apply(l1_row,axis=1)
#      15
#      16 # ---- parameters that can be tweaked:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in apply_standard(self)
#     258
#     259         # wrap results
# --> 260         return self.wrap_results()
#     261
#     262     def apply_series_generator(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in wrap_results(self)
#     306         if len(results) > 0 and is_sequence(results[0]):
#     307
# --> 308             return self.wrap_results_for_axis()
#     309
#     310         # dict of scalars
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in wrap_results_for_axis(self)
#     392         # we may want to infer results
#     393         else:
# --> 394             result = self.infer_to_same_shape()
#     395
#     396         return result
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/apply.py in infer_to_same_shape(self)
#     401
#     402         result = self.obj._constructor(data=results)
# --> 403         result = result.T
#     404
#     405         # set the index
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in transpose(self, *args, **kwargs)
#    2696         """
#    2697         nv.validate_transpose(args, dict())
# -> 2698         return super(DataFrame, self).transpose(1, 0, **kwargs)
#    2699
#    2700     T = property(transpose)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in transpose(self, *args, **kwargs)
#     674         new_axes = self._construct_axes_dict_from(self, [self._get_axis(x)
#     675                                                          for x in axes_names])
# --> 676         new_values = self.values.transpose(axes_numbers)
#     677         if kwargs.pop('copy', None) or (len(args) and args[-1]):
#     678             new_values = new_values.copy()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in values(self)
#    5323         """
#    5324         self._consolidate_inplace()
# -> 5325         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5326
#    5327     @property
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/managers.py in as_array(self, transpose, items)
#     766             arr = np.asarray(mgr.blocks[0].get_values())
#     767         else:
# --> 768             arr = mgr._interleave()
#     769
#     770         return arr.transpose() if transpose else arr
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals/managers.py in _interleave(self)
#     785             dtype = 'object'
#     786
# --> 787         result = np.empty(self.shape, dtype=dtype)
#     788
#     789         itemmask = np.zeros(self.shape[0])
#
# MemoryError:

# %%
#Write adjacency matrix data to csv
# adjdf.to_csv('data/cargo-adjdf.csv')
# adjdf_from_csv = pd.read_csv('data/cargo-adjdf.csv', delimiter=',');

# %%
def g_from_adj(adjdf):
    adjmat = adjdf.values
    # construct the graph from the adjacency matrix
    g = ig.Graph.Adjacency(adjmat.astype(bool).tolist())
    g.es['weight'] = adjmat[adjmat.nonzero()]
    g.vs['label'] = labels
    return g

def page_rank(g):
    # reset = [e_proj] * len(proj) + [e_account] * len(acc)
    reset = [e_proj] * len(proj_ids)
    page_rank = g.personalized_pagerank(reset=reset, niter=niter);
    return pd.DataFrame({'ID': proj_ids, 'Name': labels, 'page_rank': page_rank})

# adjdf_from_csv for using the stored data
# adjdf for the data from memory
g = g_from_adj(adjdf)

page_rank = page_rank(g)
page_rank_top100 = page_rank.sort_values(by=['page_rank'], ascending=False).head(100)

# %%
#Write page_rank data to csv
page_rank.sort_values(by=['page_rank'], ascending=False).to_csv('data/cargo-pagerank.csv', index= False)

# %%
page_rank_top100
# Out:
#             ID                      Name  page_rank
# 3563   1369785                num-traits   0.059415
# 1005    428702                      rand   0.035209
# 518      31533                    winapi   0.033656
# 425      31384                     serde   0.026141
# 242      31115                      libc   0.022697
# 4550   1629953              serde_derive   0.020821
# 16285  3414109  rustc-std-workspace-core   0.019508
# 396      31342           rustc-serialize   0.014597
# 7998   2353652               proc-macro2   0.013991
# 1542    783030                    clippy   0.013728
# 259      31140                       log   0.013532
# 236      31105               lazy_static   0.011097
# 16220   796081              winapi-build   0.011065
# 1543    783031            compiletest_rs   0.011040
# 4593   1638796                     quote   0.010733
# 301      31212                       num   0.010618
# 379      31311                     regex   0.010106
# 368      31296                quickcheck   0.008700
# 2077    922107                serde_json   0.008614
# 8962   2448837                 rand_core   0.007968
# 4629   1647361                       syn   0.007255
# 1078    653520                   tempdir   0.006053
# 16226    30798                  bitflags   0.005939
# 1143    702557              serde_macros   0.005612
# 1008    428781                 byteorder   0.005509
# 228      31094              kernel32-sys   0.005430
# 16328   770837               unicode-xid   0.005391
# 4102   1559116                serde_test   0.005060
# 4335   1595835                   futures   0.004789
# 423      31382                    semver   0.004690
# ...        ...                       ...        ...
# 26       30774                 ansi_term   0.001548
# 476      31457                      term   0.001509
# 3558   1369780                num-bigint   0.001500
# 6979   2251865    serde_derive_internals   0.001498
# 3562   1369784                  num-iter   0.001485
# 988     396253                     bytes   0.001390
# 6565   2181387                    stdweb   0.001382
# 221      31085                 itertools   0.001361
# 13399  3187174               packed_simd   0.001332
# 16349  3286418             rand_xorshift   0.001322
# 16264   759818             unicode-width   0.001321
# 8010   2354817                   magenta   0.001295
# 1010    428784               rand_macros   0.001291
# 8716   2448528            fuchsia-zircon   0.001291
# 15134  3370220                   rand_hc   0.001270
# 14611  3286426                  rand_pcg   0.001270
# 14909  3334452               rand_chacha   0.001268
# 14879  3332574                rand_isaac   0.001261
# 10156  2576150                  cloudabi   0.001261
# 7053   2262792                   average   0.001261
# 14880  3332579                rand_hc128   0.001261
# 74       30848                   collect   0.001255
# 3561   1369783              num-rational   0.001227
# 4650   1649939                tokio-core   0.001222
# 11267  2676093              futures-core   0.001158
# 112      30920                    docopt   0.001153
# 2344    993776                   walkdir   0.001132
# 16292   432620                      void   0.001128
# 16329  1803959             redox_syscall   0.001125
# 6840   2216325               serde_bytes   0.001116
#
# [100 rows x 3 columns]

# %%
layout = g.layout("large")
vertex_weights = [i * 100 for i in page_rank['page_rank'].tolist()]
adjmat = adjdf.values
edge_weights = [i * 10 for i in adjmat[adjmat.nonzero()]]
#ig.plot(g, vertex_size=vertex_weights, vertex_color=(["blue"] * len(proj_ids)), vertex_label_dist=1, edge_width=edge_weights, layout=layout)
